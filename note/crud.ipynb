# %%
import psycopg

# %%
#  history | grep docker | grep run
DB_CONFIG = {
    "dbname": "sunsindb",
    "user": "sunsin",
    "password": "mysecretpassword",
    "host": "localhost",
    "port": "5432"
}

# %%
psycopg.connect(**DB_CONFIG)
# Out:
# <psycopg.Connection [IDLE] (host=localhost user=sunsin database=sunsindb) at 0x7fa0b2523f10>

# %%
psycopg.connect(dbname="sunsindb", 
                user="sunsin", 
                password="mysecretpassword",
                host="localhost",
                port="5432")
# Out:
# <psycopg.Connection [IDLE] (host=localhost user=sunsin database=sunsindb) at 0x7fa0b269bf10>

# %%
def get_connection():
    return psycopg.connect(**DB_CONFIG)

# %%
conn = get_connection()

# %%
cursor = conn.cursor()

# %%
cursor.execute(
    "INSERT INTO lunch_menu (menu_name, member_name, dt) VALUES (%s, %s, %s);",
    ('테스트음식', '테스트맴버','2000-11-11')
)
# Out:
# <psycopg.Cursor [COMMAND_OK] [INTRANS] (host=localhost user=sunsin database=sunsindb) at 0x7fa0b0de68d0>

# %%
conn.commit()

# %%
cursor.close()
